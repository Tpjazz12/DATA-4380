# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import NBA statistic from NBA API (player statistics and teams standings)

# %%
from nba_api.stats.endpoints import leaguedashplayerstats, leaguestandings

# %% [markdown]
#  Get team standings and player statistics dataset

# %%
#Standing dataset
standings = leaguestandings.LeagueStandings(season='2022-23').get_data_frames()[0]
standings
# Out:
#    LeagueID SeasonID      TeamID       TeamCity       TeamName Conference  \
# 0        00    22022  1610612743         Denver        Nuggets       West
# 1        00    22022  1610612749      Milwaukee          Bucks       East
# 2        00    22022  1610612738         Boston        Celtics       East
# 3        00    22022  1610612763        Memphis      Grizzlies       West
# 4        00    22022  1610612758     Sacramento          Kings       West
# 5        00    22022  1610612755   Philadelphia          76ers       East
# 6        00    22022  1610612739      Cleveland      Cavaliers       East
# 7        00    22022  1610612756        Phoenix           Suns       West
# 8        00    22022  1610612752       New York         Knicks       East
# 9        00    22022  1610612746             LA       Clippers       West
# 10       00    22022  1610612744   Golden State       Warriors       West
# 11       00    22022  1610612751       Brooklyn           Nets       East
# 12       00    22022  1610612748          Miami           Heat       East
# 13       00    22022  1610612747    Los Angeles         Lakers       West
# 14       00    22022  1610612737        Atlanta          Hawks       East
# 15       00    22022  1610612740    New Orleans       Pelicans       West
# 16       00    22022  1610612750      Minnesota   Timberwolves       West
# 17       00    22022  1610612761        Toronto        Raptors       East
# 18       00    22022  1610612741        Chicago          Bulls       East
# 19       00    22022  1610612760  Oklahoma City        Thunder       West
# 20       00    22022  1610612764     Washington        Wizards       East
# 21       00    22022  1610612742         Dallas      Mavericks       West
# 22       00    22022  1610612762           Utah           Jazz       West
# 23       00    22022  1610612754        Indiana         Pacers       East
# 24       00    22022  1610612753        Orlando          Magic       East
# 25       00    22022  1610612757       Portland  Trail Blazers       West
# 26       00    22022  1610612766      Charlotte        Hornets       East
# 27       00    22022  1610612759    San Antonio          Spurs       West
# 28       00    22022  1610612765        Detroit        Pistons       East
# 29       00    22022  1610612745        Houston        Rockets       West
#
#    ConferenceRecord  PlayoffRank ClinchIndicator   Division  ...   May   Jun  \
# 0             32-15            1            - nw  Northwest  ...  None  None
# 1             32-16            1             - c    Central  ...  None  None
# 2             31-17            2             - x   Atlantic  ...  None  None
# 3             29-20            2            - sw  Southwest  ...  None  None
# 4             31-16            3             - x    Pacific  ...  None  None
# 5             31-16            3             - x   Atlantic  ...  None  None
# 6             31-17            4             - x    Central  ...  None  None
# 7             27-20            4                    Pacific  ...  None  None
# 8             30-19            5                   Atlantic  ...  None  None
# 9             24-24            5                    Pacific  ...  None  None
# 10            27-21            6                    Pacific  ...  None  None
# 11            28-21            6                   Atlantic  ...  None  None
# 12            21-27            7                  Southeast  ...  None  None
# 13            23-24            7                    Pacific  ...  None  None
# 14            24-24            8                  Southeast  ...  None  None
# 15            27-21            8                  Southwest  ...  None  None
# 16            27-22            9                  Northwest  ...  None  None
# 17            23-24            9                   Atlantic  ...  None  None
# 18            26-23           10                    Central  ...  None  None
# 19            23-25           10                  Northwest  ...  None  None
# 20            20-28           11                  Southeast  ...  None  None
# 21            27-23           11                  Southwest  ...  None  None
# 22            23-25           12                  Northwest  ...  None  None
# 23            23-25           12                    Central  ...  None  None
BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0    13   5   8  0.385  ...       475        397      473       478       448
# 1    33  26   7  0.788  ...       475        478      435       498       364
# 2    68  31  37  0.456  ...       345        290      384       405       212
# 3    65  44  21  0.677  ...        70         32      215        54        81
# 4    59  30  29  0.508  ...       331        295      361       336       390
# ..   ..  ..  ..    ...  ...       ...        ...      ...       ...       ...
# 523  61  18  43  0.295  ...        67        126       26       111       143
# 524  73  36  37  0.493  ...       289         19      155        45        21
# 525  50  33  17  0.660  ...       155        327      194       270       340
# 526  36  21  15  0.583  ...       392        413      283       319       333
# 527  29  17  12  0.586  ...       111          2      128         6        17
#
#      PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0                341                   485       234        35
# 1                322                   430       234        35
# 2                159                   278       234        35
# 3                  2                    76        60        35
# 4                218                   390       234        35
# ..               ...                   ...       ...       ...
# 523              487                   129        73        35
# 524              217                    44       150        35
# 525              422                   366       180        35
# 526              403                   384       234        35
# 527               16                    22       101        35
#
#      WNBA_FANTASY_PTS_RANK
# 0                      473
# 1                      403
# 2                      262
# 3                       87
# 4                      395
# ..                     ...
# 523                    134
# 524                     31
# 525                    372
# 526                    373
# 527                     28
#
# [528 rows x 66 columns]

# %% [markdown]
# Merge team standings with player stats by Team ID

# %%
df = pd.merge(player_stats, standings, left_on='TEAM_ID', right_on='TeamID', how='outer')

# %% [markdown]
# ### Feature engineering
# Including these two features can help to capture important information about a team's performance that is not captured by other features such as points per game or rebounds per game.

# %%
df['AssistRatio'] = df['AST'] / (df['AST'] + df['TOV'])
#Indication of a player's ability to assist their teamates without turning the ball over

df['WinStreak'] = df['W'] - df['L']
#Indication of how many consecutive game has won (if value +) or lost (if value -)

# %% [markdown]
# Features are selected to calculate the percentage of winning

# %%
feature_columns = ['PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'FG_PCT', 'FT_PCT', 'FG3_PCT', 'W_PCT', 'AssistRatio', 'WinStreak']

# %%
feature_weights = {
    'PTS': 0.1,
    'REB': 0.15,
    'AST': 0.15,
    'STL': 0.05,
    'BLK': 0.05,
    'TOV': -0.15,
    'FG_PCT': 0.1,
    'FT_PCT': 0.05,
    'FG3_PCT': 0.05,
    'W_PCT': 0.2,
    'AssistRatio': 0.15,
    'WinStreak': 0.1
}

# %% [markdown]
# ### Aggregate team stats using 'TEAM_ID', 'Conference', 'TeamName', 'TeamCity', and 'PlayoffRank'

# %%
team_stats = df.groupby(['TEAM_ID', 'Conference', 'TeamName', 'TeamCity', 'PlayoffRank']).sum().reset_index()
team_stats
# Out:
#        TEAM_ID Conference       TeamName       TeamCity  PlayoffRank  \
# 0   1610612737       East          Hawks        Atlanta            8
# 1   1610612738       East        Celtics         Boston            2
# 2   1610612739       East      Cavaliers      Cleveland            4
# 3   1610612740       West       Pelicans    New Orleans            8
# 4   1610612741       East          Bulls        Chicago           10
# 5   1610612742       West      Mavericks         Dallas           11
# 6   1610612743       West        Nuggets         Denver            1
# 7   1610612744       West       Warriors   Golden State            6
# 8   1610612745       West        Rockets        Houston           15
# 9   1610612746       West       Clippers             LA            5
# 10  1610612747       West         Lakers    Los Angeles            7
# 11  1610612748       East           Heat          Miami            7
# 12  1610612749       East          Bucks      Milwaukee            1
# 13  1610612750       West   Timberwolves      Minnesota            9
# 14  1610612751       East           Nets       Brooklyn            6
# 15  1610612752       East         Knicks       New York            5
# 16  1610612753       East          Magic        Orlando           13
# 17  1610612754       East         Pacers        Indiana           12
# 4                    0    1927.8       1907.4          20.4     9.167670
# 5                    0    2389.8       2379.3          10.5    12.008760
# 6                    0    1857.6       1798.4          59.2     9.655471
# 7                    0    2011.1       1999.2          13.6     9.852409
# 8                    0    1657.5       1782.0        -124.5     9.411122
# 9                    0    2035.8       2028.6           5.4    11.543272
# 10                   0    1980.5       1980.5           0.0    10.925165
# 11                   0    1847.9       1866.6         -18.7     9.169644
# 12                   0    2106.0       2035.8          70.2    10.212396
# 13                   0    2080.8       2088.0          -7.2    11.258225
# 14                   0    2160.3       2143.2          17.1    11.080634
# 15                   0    1734.0       1689.0          45.0     9.000377
# 16                   0    1677.0       1711.5         -34.5     9.180158
# 17                   0    1972.0       2023.0         -52.7    10.402282
# 18                   0    1843.2       1768.0          75.2     9.038369
# 19                   0    1816.0       1784.0          32.0    10.172660
# 20                  19    2154.6       2215.4         -62.7    12.119751
# 21                   0    2424.0       2360.0          64.0    11.078340
# 22                   0    2466.2       2699.4        -233.2    13.093772
# 23                   0    1878.4       1862.4          16.0    10.338524
# 24                   0    2145.1       2122.3          20.9    11.796219
# 25                   0    2226.8       2240.1         -13.3    11.606644
# 26                   0    1985.6       1912.5          73.1    10.688945
# 27                   0    2373.0       2389.8         -16.8    12.759775
# 28                  19    2103.3       2253.4        -150.1    10.358617
# 29                  17    1890.4       1995.8        -105.4    10.160052
#
#     WinStreak
# 0         -64
# 1         297
# 2         198
# 3          -1
# 4         -35
# 5         -16
# 6         255
# 7          52
# 8        -393
# 9         -18
# 10         39
# 11         19
# 12        318
# 13        -18
# 14         24
# 15        116
# 16        -96
# 17        -83
# 18        236
# 19         66
# 20       -146
# 21        188
# 22       -382
# 23        -37
# 24        -23
# 25        -47
# 26        240
# 27       -106
# 28       -427
# 29       -214
#
# [30 rows x 92 columns]

# %% [markdown]
# ### Calculate weighted score for each team

# %%
team_stats['Score'] = team_stats[feature_columns].apply(lambda x: sum(x * [feature_weights[col] for col in feature_columns]), axis=1)
team_stats['Score']
# Out:
# 12    67.386009
# 1     63.448056
# 18    55.480555
# 2     49.194734
# 15    43.582207
# 14    36.087545
# 11    34.967297
# 24    33.490883
# 0     27.113730
# 4     25.021500
# 17    24.636192
# 27    21.486666
# 16    20.531074
# 29    10.451058
# 28    -8.661407
# 26    58.940092
# 6     58.529871
# 21    49.548001
# 19    42.078449
# 10    39.224225
# 7     38.984761
# 9     36.759941
# 3     33.846558
# 5     32.618814
# 13    32.144884
# 23    27.860479
# 25    27.528297
# 20    20.847313
# 22    -1.582634
# 8    -12.872232
# Name: Score, dtype: float64

# %% [markdown]
# Sort teams by score and rank them

# %%
team_stats = team_stats.sort_values(['Conference', 'Score'], ascending=[True, False])
team_stats['Rank'] = team_stats.groupby('Conference').cumcount() + 1

# %% [markdown]
# Add a new column for the difference between the calculated rank and the PlayoffRank

# %%
team_stats['RankDifference'] = team_stats['Rank'] - team_stats['PlayoffRank']

# %% [markdown]
# Split teams into conferences

# %%
eastern_conference = team_stats[team_stats['Conference'] == 'East'][['TeamCity', 'TeamName', 'Rank', 'PlayoffRank', 'RankDifference']]
western_conference = team_stats[team_stats['Conference'] == 'West'][['TeamCity', 'TeamName', 'Rank', 'PlayoffRank', 'RankDifference']]

# %% [markdown]
# ### Ranking the teams
# Ranking the team by the feature weight score and showing the difference between PlayoffRank in standings dataset

# %%
print("Eastern Conference Rankings:\n", eastern_conference)
print("Western Conference Rankings:\n", western_conference)
# Out:
# Eastern Conference Rankings:
#          TeamCity   TeamName  Rank  PlayoffRank  RankDifference
# 12     Milwaukee      Bucks     1            1               0
# 1         Boston    Celtics     2            2               0
# 18  Philadelphia      76ers     3            3               0
# 2      Cleveland  Cavaliers     4            4               0
# 15      New York     Knicks     5            5               0
# 14      Brooklyn       Nets     6            6               0
# 11         Miami       Heat     7            7               0
# 24       Toronto    Raptors     8            9              -1
# 0        Atlanta      Hawks     9            8               1
# 4        Chicago      Bulls    10           10               0
# 17       Indiana     Pacers    11           12              -1
# 27    Washington    Wizards    12           11               1
# 16       Orlando      Magic    13           13               0
# 29     Charlotte    Hornets    14           14               0
# 28       Detroit    Pistons    15           15               0
# Western Conference Rankings:
#           TeamCity       TeamName  Rank  PlayoffRank  RankDifference
# 26        Memphis      Grizzlies     1            2              -1
# 6          Denver        Nuggets     2            1               1
# 21     Sacramento          Kings     3            3               0
# 19        Phoenix           Suns     4            4               0
# 10    Los Angeles         Lakers     5            7              -2
# 7    Golden State       Warriors     6            6               0
# 9              LA       Clippers     7            5               2
# 3     New Orleans       Pelicans     8            8               0
# 5          Dallas      Mavericks     9           11              -2
# 13      Minnesota   Timberwolves    10            9               1
# 23  Oklahoma City        Thunder    11           10               1
# 25           Utah           Jazz    12           12               0
# 20       Portland  Trail Blazers    13           13               0
# 22    San Antonio          Spurs    14           14               0
# 8         Houston        Rockets    15           15               0

# %% [markdown]
# ### Predict the top-ranked teams from each conference as NBA Finals contenders

# %%
eastern_finalist = team_stats[team_stats['Conference'] == 'East'].iloc[0]
western_finalist = team_stats[team_stats['Conference'] == 'West'].iloc[0]

# %% [markdown]
# Normalize the scores of the two finalists

# %%
total_score = eastern_finalist['Score'] + western_finalist['Score']
eastern_finalist['NormalizedScore'] = eastern_finalist['Score'] / total_score
western_finalist['NormalizedScore'] = western_finalist['Score'] / total_score

# %% [markdown]
# Calculate the winning percentage for each finalist

# %%
eastern_finalist['WinningPercentage'] = eastern_finalist['NormalizedScore'] / (eastern_finalist['NormalizedScore'] + western_finalist['NormalizedScore'])
western_finalist['WinningPercentage'] = western_finalist['NormalizedScore'] / (eastern_finalist['NormalizedScore'] + western_finalist['NormalizedScore'])

# %% [markdown]
# Display the predicted NBA Finals contenders and their winning percentages

# %%
print("Eastern Conference Finalist:\n", eastern_finalist[['TeamCity', 'TeamName', 'Score','WinningPercentage']])
print("Western Conference Finalist:\n", western_finalist[['TeamCity', 'TeamName', 'Score','WinningPercentage']])
# Out:
# Eastern Conference Finalist:
#  TeamCity             Milwaukee
# TeamName                 Bucks
# Score                67.386009
# WinningPercentage     0.533429
# Name: 12, dtype: object
# Western Conference Finalist:
#  TeamCity               Memphis
# TeamName             Grizzlies
# Score                58.940092
# WinningPercentage     0.466571
# Name: 26, dtype: object

# %% [markdown]
# ### Predict the champion

# %%
if eastern_finalist['WinningPercentage'] > western_finalist['WinningPercentage']:
    champion = eastern_finalist
else:
    champion = western_finalist

print("Predicted NBA Champion:\n", champion[['TeamCity', 'TeamName', 'Score', 'NormalizedScore', 'WinningPercentage']])
# Out:
# Predicted NBA Champion:
#  TeamCity             Milwaukee
# TeamName                 Bucks
# Score                67.386009
# NormalizedScore       0.533429
# WinningPercentage     0.533429
# Name: 12, dtype: object

# %% [markdown]
# ### Combining the calculated scores with the playoff ranks to predict the NBA champion.

# %% [markdown]
# By taking the reciprocal of the PlayoffRank, we create a new metric where higher values are considered better. This makes it easier to work with the other metrics in our model, where higher values are also considered better.

# %%
team_stats['InversePlayoffRank'] = 1 / team_stats['PlayoffRank']
#The InversePlayoffRank is calculated as the reciprocal of the PlayoffRank. 
#The PlayoffRank is a ranking of the teams where a lower rank is considered better. 
#The best team has a rank of 1, the second-best team has a rank of 2, and so on.

# %%
team_stats['NormalizedScore'] = team_stats['Score'] / team_stats['Score'].sum()

# %%
eastern_finalist = team_stats[team_stats['Conference'] == 'East'].iloc[0]
western_finalist = team_stats[team_stats['Conference'] == 'West'].iloc[0]

# %%
eastern_finalist['NormalizedInversePlayoffRank'] = eastern_finalist['InversePlayoffRank'] / (eastern_finalist['InversePlayoffRank'] + western_finalist['InversePlayoffRank'])
western_finalist['NormalizedInversePlayoffRank'] = western_finalist['InversePlayoffRank'] / (eastern_finalist['InversePlayoffRank'] + western_finalist['InversePlayoffRank'])

# %% [markdown]
# The playoff_rank_weight determines the importance of the playoff rank in the prediction.

# %%
playoff_rank_weight = 0.3

# %%
eastern_finalist['AdjustedWinningPercentage'] = (1 - playoff_rank_weight) * eastern_finalist['NormalizedScore'] + playoff_rank_weight * eastern_finalist['NormalizedInversePlayoffRank']
western_finalist['AdjustedWinningPercentage'] = (1 - playoff_rank_weight) * western_finalist['NormalizedScore'] + playoff_rank_weight * western_finalist['NormalizedInversePlayoffRank']

# %%
print("Eastern Conference Finalist:\n", eastern_finalist[['TeamCity', 'TeamName', 'Score', 'NormalizedScore', 'AdjustedWinningPercentage']])
print("Western Conference Finalist:\n", western_finalist[['TeamCity', 'TeamName', 'Score', 'NormalizedScore', 'AdjustedWinningPercentage']])
# Out:
# Eastern Conference Finalist:
#  TeamCity                     Milwaukee
# TeamName                         Bucks
# Score                        67.386009
# NormalizedScore               0.533429
# AdjustedWinningPercentage     0.247711
# Name: 12, dtype: object
# Western Conference Finalist:
#  TeamCity                       Memphis
# TeamName                     Grizzlies
# Score                        58.940092
# NormalizedScore               0.466571
# AdjustedWinningPercentage     0.141731
# Name: 26, dtype: object

# %%
if eastern_finalist['AdjustedWinningPercentage'] > western_finalist['AdjustedWinningPercentage']:
    champion = eastern_finalist
else:
    champion = western_finalist

print("Predicted NBA Champion:\n", champion[['TeamCity', 'TeamName', 'Score', 'NormalizedScore', 'AdjustedWinningPercentage']])
# Out:
# Predicted NBA Champion:
#  TeamCity                     Milwaukee
# TeamName                         Bucks
# Score                        67.386009
# NormalizedScore               0.068158
# AdjustedWinningPercentage     0.247711
# Name: 12, dtype: object
