# %%
pip install nba-api
# Out:
# Requirement already satisfied: nba-api in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.1.14)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nba-api) (1.23.3)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nba-api) (2.28.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->nba-api) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->nba-api) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->nba-api) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->nba-api) (2022.12.7)
#
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguestandings, teamdashboardbyteamperformance, commonallplayers

# %% [markdown]
#  Fetch the current NBA standings using the LeagueStandings class from the nba-api

# %%
def get_standings():
    standings_data = leaguestandings.LeagueStandings().get_data_frames()[0]
    return standings_data

# %%
standing_data = get_standings()
standing = standing_data[['TeamCity','TeamName','Conference','WinPCT','PlayoffRank']]
standing
# Out:
#          TeamCity       TeamName Conference  WinPCT  PlayoffRank
# 0          Denver        Nuggets       West   0.671            1
# 1       Milwaukee          Bucks       East   0.714            1
# 2      Sacramento          Kings       West   0.609            2
# 3          Boston        Celtics       East   0.686            2
# 4         Memphis      Grizzlies       West   0.603            3
# 5    Philadelphia          76ers       East   0.681            3
# 6       Cleveland      Cavaliers       East   0.616            4
# 7         Phoenix           Suns       West   0.543            4
# 8              LA       Clippers       West   0.529            5
# 9        New York         Knicks       East   0.577            5
# 10   Golden State       Warriors       West   0.507            6
# 11       Brooklyn           Nets       East   0.557            6
# 12          Miami           Heat       East   0.535            7
# 13      Minnesota   Timberwolves       West   0.500            7
# 14         Dallas      Mavericks       West   0.500            8
# 15        Atlanta          Hawks       East   0.500            8
# 16    Los Angeles         Lakers       West   0.486            9
# 17        Toronto        Raptors       East   0.486            9
# 18  Oklahoma City        Thunder       West   0.486           10
# 19        Indiana         Pacers       East   0.457           10
# 20     Washington        Wizards       East   0.457           11
# 21           Utah           Jazz       West   0.478           11
# 22    New Orleans       Pelicans       West   0.478           12
# 23        Chicago          Bulls       East   0.456           12
# 24       Portland  Trail Blazers       West   0.449           13
# 25        Orlando          Magic       East   0.400           13
# 26    San Antonio          Spurs       West   0.261           14
# 27      Charlotte        Hornets       East   0.306           14
# 28        Houston        Rockets       West   0.246           15
# 29        Detroit        Pistons       East   0.225           15

# %% [markdown]
# Graph show the win percentages of every teams

# %%
def plot_win_percentages(east_teams, west_teams):
    east_teams = east_teams[['TeamName', 'WinPCT']].sort_values('WinPCT', ascending=False)
    west_teams = west_teams[['TeamName', 'WinPCT']].sort_values('WinPCT', ascending=False)

    fig, ax = plt.subplots(2, 1, figsize=(12, 12))

    ax[0].bar(east_teams['TeamName'], east_teams['WinPCT'])
    ax[0].set_title('Eastern Conference Win Percentages')
    ax[0].set_ylabel('Win Percentage')
    ax[0].tick_params(axis='x', rotation=45)

    ax[1].bar(west_teams['TeamName'], west_teams['WinPCT'])
    ax[1].set_title('Western Conference Win Percentages')
    ax[1].set_ylabel('Win Percentage')
    ax[1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# %%
east_teams, west_teams = get_top_teams(standing)

plot_win_percentages(east_teams, west_teams)

# %% [markdown]
# Filter the top 8 teams of each conference bases on Win Percentage and Playoff Rank

# %%
def get_top_teams(standing, num_teams=8):
    east_teams = standing[standing['Conference'] == 'East'].head(num_teams)
    west_teams = standing[standing['Conference'] == 'West'].head(num_teams)
    return east_teams, west_teams

# %%
get_top_teams(standing, num_teams=8)
# Out:
# (        TeamCity   TeamName Conference  WinPCT  PlayoffRank
# 1      Milwaukee      Bucks       East   0.714            1
# 3         Boston    Celtics       East   0.686            2
# 5   Philadelphia      76ers       East   0.681            3
# 6      Cleveland  Cavaliers       East   0.616            4
# 9       New York     Knicks       East   0.577            5
# 11      Brooklyn       Nets       East   0.557            6
# 12         Miami       Heat       East   0.535            7
# 15       Atlanta      Hawks       East   0.500            8,         TeamCity      TeamName Conference  WinPCT  PlayoffRank
# 0         Denver       Nuggets       West   0.671            1
# 2     Sacramento         Kings       West   0.609            2
# 4        Memphis     Grizzlies       West   0.603            3
# 7        Phoenix          Suns       West   0.543            4
# 8             LA      Clippers       West   0.529            5
# 10  Golden State      Warriors       West   0.507            6
# 13     Minnesota  Timberwolves       West   0.500            7
# 14        Dallas     Mavericks       West   0.500            8)

# %%
standing = standing_data[['TeamName','Conference','WinPCT']]
standing
# Out:
#          TeamName Conference  WinPCT
# 0         Nuggets       West   0.671
# 1           Bucks       East   0.714
# 2           Kings       West   0.609
# 3         Celtics       East   0.686
# 4       Grizzlies       West   0.603
# 5           76ers       East   0.681
# 6       Cavaliers       East   0.616
# 7            Suns       West   0.543
# 8        Clippers       West   0.529
# 9          Knicks       East   0.577
# 10       Warriors       West   0.507
# 11           Nets       East   0.557
# 12           Heat       East   0.535
# 13   Timberwolves       West   0.500
# 14      Mavericks       West   0.500
# 15          Hawks       East   0.500
# 16         Lakers       West   0.486
# 17        Raptors       East   0.486
# 18        Thunder       West   0.486
# 19         Pacers       East   0.457
# 20        Wizards       East   0.457
# 21           Jazz       West   0.478
# 22       Pelicans       West   0.478
# 23          Bulls       East   0.456
# 24  Trail Blazers       West   0.449
# 25          Magic       East   0.400
# 26          Spurs       West   0.261
# 27        Hornets       East   0.306
# 28        Rockets       West   0.246
# 29        Pistons       East   0.225

# %%
def predict_final_champion(east_teams, west_teams):
    east_champion = east_teams.iloc[east_teams['WinPCT'].idxmax()]
    west_champion = west_teams.iloc[west_teams['WinPCT'].idxmax()]

    if east_champion['WinPCT'] < west_champion['WinPCT']:
        return west_champion['TeamName']
    else:
        return east_champion['TeamName']

# %%
east_teams, west_teams = get_top_teams(standing)
predicted_champion = predict_final_champion(east_teams, west_teams)
print(f"The predicted NBA final champion is: {predicted_champion}")
# Out:
# The predicted NBA final champion is: Celtics

# %%
def get_team_id(team_name):
    all_teams = teams.get_teams()
    for team in all_teams:
        if team['full_name'].lower() == team_name.lower():
            return team['id']
    return None

# %%
def get_team_stats(team_name, season='2022-23'):
    team_id = get_team_id(team_name)
    
    if not team_id:
        print(f"Team '{team_name}' not found.")
        return None

    team_stats = teamdashboardbyteamperformance.TeamDashboardByTeamPerformance(
        team_id=team_id, 
        season=season,
        season_type_all_star='Regular Season'
    ).get_data_frames()[1]
    return team_stats

# %%
team_name = 'Boston Celtics'
team_stats = get_team_stats(team_name)
clean_team_stats=team_stats[['W','L','W_PCT']]
# Out:
#              GROUP_SET  GROUP_VALUE_ORDER GROUP_VALUE       GROUP_VALUE_2  GP  \
# 0   Score Differential                NaN           W      Over 20 Points   8
# 1   Score Differential                NaN           W        11-15 Points  10
# 2   Score Differential                NaN           W        16-20 Points   6
# 3   Score Differential                NaN           W         6-10 Points  12
# 4   Score Differential                NaN           W  5 Points and Under  12
# 5   Score Differential                0.0           W                 All  48
# 6   Score Differential                NaN           L  5 Points and Under   9
# 7   Score Differential                NaN           L         6-10 Points   4
# 8   Score Differential                NaN           L      Over 20 Points   1
# 9   Score Differential                NaN           L        16-20 Points   3
# 10  Score Differential                NaN           L        11-15 Points   5
# 11  Score Differential                0.0           L                 All  22
#
#      W   L  W_PCT     MIN   FGM  ...  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  \
# 0    8   0    1.0   384.0   381  ...         5         4         6         2
# 1   10   0    1.0   480.0   428  ...         4         3         7         4
# 2    6   0    1.0   288.0   270  ...         6         6         3         6
# 3   12   0    1.0   576.0   510  ...         2         1         9         5
# 4   12   0    1.0   596.0   505  ...         1         2        10         1
# 5   48   0    1.0  2324.0  2094  ...         1         1         2         1
# 6    0   9    0.0   462.0   345  ...         3         5         8         3
# 7    0   4    0.0   202.0   164  ...         8         8         4         7
# 8    0   1    0.0    48.0    40  ...        10        10         1        10
# 9    0   3    0.0   144.0   108  ...         9         9         2         9
# 10   0   5    0.0   240.0   180  ...         7         7         5         8
# 11   0  22    0.0  1096.0   837  ...         2         2         1         2
#
#     BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0          5          5        6         5         4                1
# 1          3          9        8         4         3                2
# 2          6          5        5         6         6                3
# 3          2          8        9         2         2                4
# 4          1         10       10         1         1                5
# 5          1          2        2         1         1                1
# 6          3          7        7         3         5                6
# 7          7          2        3         7         8                7
# 8         10          1        1        10        10                7
# 9          9          3        2         9         9                9
# 10         8          4        4         8         7               10
# 11         2          1        1         2         2                2
#
# [12 rows x 56 columns]

# %%
print(standings_data.columns)
# Out:
# Index(['LeagueID', 'SeasonID', 'TeamID', 'TeamCity', 'TeamName', 'Conference',
#        'ConferenceRecord', 'PlayoffRank', 'ClinchIndicator', 'Division',
#        'DivisionRecord', 'DivisionRank', 'WINS', 'LOSSES', 'WinPCT',
#        'LeagueRank', 'Record', 'HOME', 'ROAD', 'L10', 'Last10Home',
#        'Last10Road', 'OT', 'ThreePTSOrLess', 'TenPTSOrMore', 'LongHomeStreak',
#        'strLongHomeStreak', 'LongRoadStreak', 'strLongRoadStreak',
#        'LongWinStreak', 'LongLossStreak', 'CurrentHomeStreak',
#        'strCurrentHomeStreak', 'CurrentRoadStreak', 'strCurrentRoadStreak',
#        'CurrentStreak', 'strCurrentStreak', 'ConferenceGamesBack',
#        'DivisionGamesBack', 'ClinchedConferenceTitle', 'ClinchedDivisionTitle',
#        'ClinchedPlayoffBirth', 'EliminatedConference', 'EliminatedDivision',
#        'AheadAtHalf', 'BehindAtHalf', 'TiedAtHalf', 'AheadAtThird',
#        'BehindAtThird', 'TiedAtThird', 'Score100PTS', 'OppScore100PTS',
#        'OppOver500', 'LeadInFGPCT', 'LeadInReb', 'FewerTurnovers', 'PointsPG',
#        'OppPointsPG', 'DiffPointsPG', 'vsEast', 'vsAtlantic', 'vsCentral',
#        'vsSoutheast', 'vsWest', 'vsNorthwest', 'vsPacific', 'vsSouthwest',
#        'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec', 'PreAS', 'PostAS'],
#       dtype='object')

# %%
print(team_stats.columns)
# Out:
# Index(['GROUP_SET', 'GROUP_VALUE_ORDER', 'GROUP_VALUE', 'GROUP_VALUE_2', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#        'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#        'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#        'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#        'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK'],
#       dtype='object')
